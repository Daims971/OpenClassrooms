# %% [markdown]
# # Synthèse des prédictions
#
# ## On récupère ici l'ensemble des prédictions selon les variables explicatives ou cibles utilisées.

# %%
# Importation générale
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import joblib

# %%
# Importation des librairies pour la prédiction

from sklearn import model_selection

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer

from sklearn.pipeline import Pipeline
from sklearn import linear_model
from sklearn.kernel_ridge import KernelRidge
from sklearn.svm import SVR
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error

# Visualisation des diagrammes
from sklearn import set_config

# %%
## Import des modèles entrainés et de leur R2 score sur le dataset d'entraînement

# y_raw
# 01: normal
# 02: var_bonus
# 03: var_bonus + ENERGYSTARSCORE

# y_log
# 04: normal
# 05: var_bonus
# 06: var_bonus + ENERGYSTARSCORE

# y_trf
# 07: normal
# 08: var_bonus
# 09: var_bonus + ENERGYSTARSCORE


## Import des modèles entrainés

estimator_names = ['Ridge','Lasso','ENET','KRR','SVR','TREE','RF','GBR','ADA']
model_name = ['model_ridge','model_lasso','model_enet','model_krr','model_svr','model_tree','model_forest','model_xgb','model_ada']

# Cas réduit
# estimator_names = ['Ridge','Lasso','ENET','KRR','TREE','RF','ADA']
# model_name = ['model_ridge','model_lasso','model_enet','model_krr','model_tree','model_forest','model_ada']


path_folder_int = r'D:\Utilisateurs\Damien\Documents\Test_code\test_python\OCR_projets\IML\P3_\Code_projet'
# D:\Utilisateurs\Damien\Documents\Test_code\test_python\OCR_projets\IML\P3_\Code_projet
# C:\Users\daims\Mon Drive\Projet_dvlpt\Cours_dvlpt\OCR\P3_\Code_projet

path_grid = r'\grille_02_v6'
# grille_02_v6
# \grille_03_v7
# \TotalGHGEmissions\param_grid_v6_red

path_folder = path_folder_int + path_grid


estimator_01 = joblib.load(path_folder+ "/" + "estimator_01.pkl")
estimator_02 = joblib.load(path_folder+ "/" + "estimator_02.pkl")
estimator_03 = joblib.load(path_folder+ "/" + "estimator_03.pkl")
# estimator_04 = joblib.load(path_folder+ "/" + "estimator_04.pkl")
# estimator_05 = joblib.load(path_folder+ "/" + "estimator_05.pkl")
# estimator_06 = joblib.load(path_folder+ "/" + "estimator_06.pkl")
# estimator_07 = joblib.load(path_folder+ "/" + "estimator_07.pkl")
# estimator_08 = joblib.load(path_folder+ "/" + "estimator_08.pkl")
# estimator_09 = joblib.load(path_folder+ "/" + "estimator_09.pkl")


score_01 = pd.read_csv(path_folder+ "/" + "tab_score_gscv_01.csv",sep="\t",low_memory=False)
score_02 = pd.read_csv(path_folder+ "/" + "tab_score_gscv_02.csv",sep="\t",low_memory=False)
score_03 = pd.read_csv(path_folder+ "/" + "tab_score_gscv_03.csv",sep="\t",low_memory=False)

# score_01 = pd.read_csv('D:\\Utilisateurs\\Damien\\Documents\\Test_code\\test_python\\OCR_projets\\IML\\P3_\\tab_score_gscv_01.csv',sep="\t",low_memory=False)
# score_02 = pd.read_csv('D:\\Utilisateurs\\Damien\\Documents\\Test_code\\test_python\\OCR_projets\\IML\\P3_\\tab_score_gscv_02.csv',sep="\t",low_memory=False)
# score_03 = pd.read_csv('D:\\Utilisateurs\\Damien\\Documents\\Test_code\\test_python\\OCR_projets\\IML\\P3_\\tab_score_gscv_03.csv',sep="\t",low_memory=False)
# score_04 = pd.read_csv('D:\\Utilisateurs\\Damien\\Documents\\Test_code\\test_python\\OCR_projets\\IML\\P3_\\tab_score_gscv_04.csv',sep="\t",low_memory=False)
# score_05 = pd.read_csv('D:\\Utilisateurs\\Damien\\Documents\\Test_code\\test_python\\OCR_projets\\IML\\P3_\\tab_score_gscv_05.csv',sep="\t",low_memory=False)
# score_06 = pd.read_csv('D:\\Utilisateurs\\Damien\\Documents\\Test_code\\test_python\\OCR_projets\\IML\\P3_\\tab_score_gscv_06.csv',sep="\t",low_memory=False)
# score_07 = pd.read_csv('D:\\Utilisateurs\\Damien\\Documents\\Test_code\\test_python\\OCR_projets\\IML\\P3_\\tab_score_gscv_07.csv',sep="\t",low_memory=False)
# score_08 = pd.read_csv('D:\\Utilisateurs\\Damien\\Documents\\Test_code\\test_python\\OCR_projets\\IML\\P3_\\tab_score_gscv_09.csv',sep="\t",low_memory=False)
# score_09 = pd.read_csv('D:\\Utilisateurs\\Damien\\Documents\\Test_code\\test_python\\OCR_projets\\IML\\P3_\\tab_score_gscv_09.csv',sep="\t",low_memory=False)


mse_01 = joblib.load("mse_01.pkl")
mse_02 = joblib.load("mse_02.pkl")
mse_03 = joblib.load("mse_03.pkl")
# mse_04 = joblib.load("mse_04.pkl")
# mse_05 = joblib.load("mse_05.pkl")
# mse_06 = joblib.load("mse_06.pkl")
# mse_07 = joblib.load("mse_07.pkl")
# mse_08 = joblib.load("mse_08.pkl")
# mse_09 = joblib.load("mse_09.pkl")


msle_01 = joblib.load("msle_01.pkl")
msle_02 = joblib.load("msle_02.pkl")
msle_03 = joblib.load("msle_03.pkl")
# msle_04 = joblib.load("msle_04.pkl")
# msle_05 = joblib.load("msle_05.pkl")
# msle_06 = joblib.load("msle_06.pkl")
# msle_07 = joblib.load("msle_07.pkl")
# msle_08 = joblib.load("msle_08.pkl")
# msle_09 = joblib.load("msle_09.pkl")

# %%
## Import des données nettoyées

data = pd.read_csv('D:\\Utilisateurs\\Damien\\Documents\\Test_code\\test_python\\OCR_projets\\IML\\P3_\\data_clean.csv',sep="\t",low_memory=False)
data.isnull().sum(axis=0)
# Out:
# YearBuilt                             0
# NumberofBuildings                     0
# NumberofFloors                        0
# PropertyGFAParking                    0
# PropertyGFABuilding(s)                0
# LargestPropertyUseTypeGFA             0
# SecondLargestPropertyUseTypeGFA       0
# ThirdLargestPropertyUseTypeGFA        0
# ENERGYSTARScore                     565
# SiteEnergyUse(kBtu)                   0
# SiteEnergyUseWN(kBtu)                 0
# TotalGHGEmissions                     0
# BuildingType                          0
# PrimaryPropertyType                   0
# LargestPropertyUseType                0
# SecondLargestPropertyUseType        805
# ThirdLargestPropertyUseType        1309
# CouncilDistrictCode                   0
# NbFloorsByLargestGFA                  0
# NbFloorSquare                         0
# LargestGFASquare                      0
# LargestGFAByNbFloors                  0
# PropertyGFABuildingByNbFloors         0
# dtype: int64

# %%
data_ess = data.dropna(subset=['ENERGYSTARScore'])
data_ess.isnull().sum(axis=0)
# Out:
# YearBuilt                            0
# NumberofBuildings                    0
# NumberofFloors                       0
# PropertyGFAParking                   0
# PropertyGFABuilding(s)               0
# LargestPropertyUseTypeGFA            0
# SecondLargestPropertyUseTypeGFA      0
# ThirdLargestPropertyUseTypeGFA       0
# ENERGYSTARScore                      0
# SiteEnergyUse(kBtu)                  0
# SiteEnergyUseWN(kBtu)                0
# TotalGHGEmissions                    0
# BuildingType                         0
# PrimaryPropertyType                  0
# LargestPropertyUseType               0
# SecondLargestPropertyUseType       590
# ThirdLargestPropertyUseType        935
# CouncilDistrictCode                  0
# NbFloorsByLargestGFA                 0
# NbFloorSquare                        0
# LargestGFASquare                     0
# LargestGFAByNbFloors                 0
# PropertyGFABuildingByNbFloors        0
# dtype: int64

# %% [markdown]
# ## Séparation du dataset:
# #### Colonnes brutes

# %%
list_data_exp = ['YearBuilt','NumberofBuildings', 'NumberofFloors', 'PropertyGFAParking',
       'PropertyGFABuilding(s)', 'LargestPropertyUseTypeGFA','SecondLargestPropertyUseTypeGFA','ThirdLargestPropertyUseTypeGFA',
       'BuildingType', 'PrimaryPropertyType', 'LargestPropertyUseType',
       'CouncilDistrictCode']

# %%
list_data_quanti_exp = ['YearBuilt','NumberofBuildings', 'NumberofFloors', 'PropertyGFAParking',
       'PropertyGFABuilding(s)', 'LargestPropertyUseTypeGFA','SecondLargestPropertyUseTypeGFA','ThirdLargestPropertyUseTypeGFA']

# %%
list_data_quali_exp = ['BuildingType', 'PrimaryPropertyType', 'LargestPropertyUseType',
       'CouncilDistrictCode']

# %% [markdown]
# #### Colonnes utilisant les variables bonus

# %%
list_data_exp_bonus = ['YearBuilt','NumberofBuildings', 'NumberofFloors', 'PropertyGFAParking',
       'PropertyGFABuilding(s)', 'LargestPropertyUseTypeGFA','SecondLargestPropertyUseTypeGFA','ThirdLargestPropertyUseTypeGFA',
        'NbFloorsByLargestGFA', 'NbFloorSquare', 'LargestGFASquare', 'LargestGFAByNbFloors', 'PropertyGFABuildingByNbFloors',
       'BuildingType', 'PrimaryPropertyType', 'LargestPropertyUseType',
       'CouncilDistrictCode']

# %%
list_data_quanti_exp_bonus = ['YearBuilt','NumberofBuildings', 'NumberofFloors', 'PropertyGFAParking',
       'PropertyGFABuilding(s)', 'LargestPropertyUseTypeGFA','SecondLargestPropertyUseTypeGFA','ThirdLargestPropertyUseTypeGFA'
                       , 'NbFloorsByLargestGFA', 'NbFloorSquare', 'LargestGFASquare', 'LargestGFAByNbFloors', 'PropertyGFABuildingByNbFloors']

# %% [markdown]
# #### Colonnes utilisant ENERGYSTARScore avec les variables bonus

# %%
list_data_exp_ess = ['YearBuilt','NumberofBuildings', 'NumberofFloors', 'PropertyGFAParking',
       'PropertyGFABuilding(s)', 'LargestPropertyUseTypeGFA','SecondLargestPropertyUseTypeGFA','ThirdLargestPropertyUseTypeGFA',
        'NbFloorsByLargestGFA', 'NbFloorSquare', 'LargestGFASquare', 'LargestGFAByNbFloors', 'PropertyGFABuildingByNbFloors',
                 'ENERGYSTARScore',
       'BuildingType', 'PrimaryPropertyType', 'LargestPropertyUseType',
       'CouncilDistrictCode']

# %%
list_data_quanti_exp_ess = ['YearBuilt','NumberofBuildings', 'NumberofFloors', 'PropertyGFAParking',
       'PropertyGFABuilding(s)', 'LargestPropertyUseTypeGFA','SecondLargestPropertyUseTypeGFA','ThirdLargestPropertyUseTypeGFA'
                       , 'NbFloorsByLargestGFA', 'NbFloorSquare', 'LargestGFASquare', 'LargestGFAByNbFloors', 'PropertyGFABuildingByNbFloors','ENERGYSTARScore']

# %%
X = data.loc[:,list_data_exp_bonus]
y1 = data.loc[:,['SiteEnergyUseWN(kBtu)']]
y2 = data.loc[:,['TotalGHGEmissions']]
y=y1

n_quanti_exp = len(list_data_quanti_exp)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2 , random_state = 0) # 20% des données dans le jeu de test

# %%
X_ess = data_ess.loc[:,list_data_exp_ess]
y1_ess = data_ess.loc[:,['SiteEnergyUseWN(kBtu)']]
y2_ess = data_ess.loc[:,['TotalGHGEmissions']]
y_ess=y1_ess

n_quanti_exp_ess = len(list_data_quanti_exp_ess)
X_train_ess, X_test_ess, y_train_ess, y_test_ess = model_selection.train_test_split(X_ess, y_ess, test_size=0.2 , random_state = 0) # 20% des données dans le jeu de test

# %% [markdown]
# On va utilisé un modèle de type "Dummy" comme base line de comparaiosn des scores de nos modèles. Ici, c'est la baseline de la moyenne qui est choisit, donnant par calcul un score de 0 pour la métrique R2.

# %%
# Base line depuis Dummy Regressor
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(X_train, y_train)
# Out:
# DummyRegressor()

# %%
y_pred_mean = dummy_regr.predict(X_train)
len(y_pred_mean)
# Out:
# 1328

# %%
dummy_score = dummy_regr.score(X_train, y_train)

# %% [markdown]
# Remarque: On n'a pas implémenté de gridsearchCV pour le modèle Dummy choisit car il ne dépend pas de X_train.

# %% [markdown]
# ## R2 score avec X_train, X_train_bonus, X_train_bonus_ENERGYSTARScore

# %%
score_syn_y_raw = pd.concat([score_01,score_02['Mean cv score'],score_03['Mean cv score']],axis=1)
score_syn_y_raw.columns = ['Predicateur', 'Score A', 'Score B', 'Score C']
# score_syn_y_raw

# %%
# score_syn_y_raw.loc[0,['Predicateur', 'Score A', 'Score B', 'Score C']] = ['Dummy',0,0,0]

# %%
dummy_pd = pd.DataFrame([['Dummy',dummy_score,dummy_score,dummy_score]],columns=['Predicateur', 'Score A', 'Score B', 'Score C'])
# dummy_pd

# %%
score_syn_y_raw = pd.concat([dummy_pd, score_syn_y_raw],axis=0)
# score_syn_y_raw

# %%
# plt.figure(figsize=(16, 16))
sns.heatmap(score_syn_y_raw[['Score A', 'Score B', 'Score C']], annot=True,center=0,cmap="coolwarm",yticklabels=score_syn_y_raw['Predicateur'])
plt.show()

# %% [markdown]
# Les méthodes à noyau (svr et krr) sont d'autant meilleurs au début car elles utilisent des non linéarités dans les variables.
# On note à quel point l'ajout de la variable explicative ENERGYSTARScore augmente considérablement les scores pour les méthodes ensemblistes.

# %% [markdown]
# # Evaluation du meilleur modèle
# Le modèle ayant le meilleur score R2 en moyenne sur les différents folds de test de X_train du GridSearchCV est le Gradient Boosting Regressor lorsque la variable ENERGYSTARScore est présente (autrement c'est le SVR). Récupérons ce modèle et testons son score sur le jeu de test X_test.

# %%
# Base line depuis Dummy Regressor
dummy_regr_ess = DummyRegressor(strategy="mean")
dummy_regr_ess.fit(X_train_ess, y_train_ess)
dummy_regr_ess.score(X_test_ess, y_test_ess)
# Out:
# -0.22713787112347017

# %%
# Prédiction du meilleur estimateur
estimator_03[7].score(X_test_ess, y_test_ess)
# Out:
# 0.81731814396156

# %% [markdown]
# On obtient un score meilleur que celui de 0.67 utilisé dans le dataset d'entraînement.

# %% [markdown]
# ## Evaluation des scores d'erreurs

# %% [markdown]
# Une évaluation des scores d'erreurs entre les modèles utilisant y_train via la MSLE et ceux utilisant y_train transformée par un PowerTransformers ou une fonction de type log via la MSE, dans le gridsearchCV, pour une comparaison avec des métriques comparables. Cependant, pour des raisons de temps de calcul, de consommation de puissance et de crash de la machine de travail, cela a été abandonné pour terminer l'étude assez rapidement.
# Les lignes qui suivent constituent une ébauche à cette étude abandonnée, dans le cas où l'on utiliserait pas de méthodes de scoring intégrées de gridsearchcv.

# %%
## Test des scores d'erreurs entre les prédicitons et les valeurs réelles du dataset de test

mse_mean = mean_squared_error(y_train, y_pred_mean) # pour y_log
msle_mean = mean_squared_log_error(y_train, y_pred_mean) #pour y non trf (non log)

# %%
def eval_mse(estimator_, estimator_names, X_sample, y_true ):
    #df_mse = pd.DataFrame()
    mse_list = []
    for i in range(len(estimator_names)):
        y_pred = estimator_[i].predict(X_sample)
        mse = mean_squared_error(y_true, y_pred)
        mse_list.append(mse)
        
    df_mse = pd.DataFrame({"mse":mse_list},index = estimator_names)
    return df_mse

def eval_msle(estimator_, estimator_names, X_sample, y_true ):
    #df_mse = pd.DataFrame()
    mse_list = []
    for i in range(len(estimator_names)):
        y_pred = estimator_[i].predict(X_sample)
        y_lin = 1 + np.abs( y_true.min() ) +  np.abs( y_pred.min() )
        #print("y_lin = " + str(y_lin))
        y_true_lin = y_true+y_lin.values
        y_pred_lin = y_pred+y_lin.values
        mse = mean_squared_log_error(y_true_lin, y_pred_lin)
        mse_list.append(mse)
        
    df_mse = pd.DataFrame({"msle":mse_list},index = estimator_names)
    return df_mse

# %%
# mse_01 = eval_mse(estimator_01, estimator_names, X_test, y_test )
# mse_02 = eval_mse(estimator_02, estimator_names, X_test, y_test )
# mse_03 = eval_mse(estimator_03, estimator_names, X_test, y_test )

# %%
msle_syn_y_raw = pd.concat([msle_01,msle_02['msle'],msle_03['msle']],axis=1)
msle_syn_y_raw.columns = ['Predicateur', 'Score A', 'Score B', 'Score C']
# msle_syn_y_raw

# %%
# plt.figure(figsize=(16, 16))
sns.heatmap(msle_syn_y_raw[['Score A', 'Score B', 'Score C']], annot=True,center=0,cmap="coolwarm",yticklabels=estimator_names)
plt.show()
